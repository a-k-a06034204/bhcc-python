# %% [markdown]
# Project 2 - Rock, Paper, Scissors Pseudocode

# %% [markdown]
# By: Ashley Kochapski

# %%
-Import random list

-Create a variable that holds the weapons (rock, paper, or scissors)

-while running, cpu has choice of weapons using random list

- Greet the User

-Prompt the user to play game (y/n)
    -if selectiion y:
        -Prompt user for one of three commands (r, p, or s?)
            -if player input selection == cpu selection:
                -print("We've tied!")
                -Prompt user to play again (y/n)
                    -if selection n:
                        -Print player Wins.
                        -Print player losses
                        -Print Cpu wins.
                        -Print Cpu losses
                        -Print player weapon picks (#of times weapon is picked)
                        -Print Cpu weapon picks (#of times weapon is picked)
                        -Ask input from user ("Are you sure you want to quit? (y/n)")
                            -if y:
                                -Print("Thank you for playing, goodbye!")
                                -Program quits
                            -if n:
                                -Loop back to prompt asking user to play again (y/n)
                    -if selection y:
                        -Loop back to prompt asking user one of three commands (r, p, or s?)
            -if player input selection ('r') and cpu selection ('s'):
                -Print("Looks like you won this time!")
                -Prompt user to play again (y/n)
                -if selection n:
                    -Print player Wins.
                        -Print player losses
                        -Print Cpu wins.
                        -Print Cpu losses
                        -Print player weapon picks (#of times weapon is picked)
                        -Print Cpu weapon picks (#of times weapon is picked)
                        -Ask input from user ("Are you sure you want to quit? (y/n)")
                            -if y:
                                -Print("Thank you for playing, goodbye!")
                                -Program quits
                            -if n:
                                -Loop back to prompt asking user to play again (y/n)
                -if selection y:
                        -Loop back to prompt asking user one of three commands (r, p, or s?)
            -if player input selection ('p') and cpu selection ('r'):
                -Print("Looks like you won this time!")
                -Prompt user to play again (y/n)
                -if selection n:
                    -Print player Wins.
                        -Print player losses
                        -Print Cpu wins.
                        -Print Cpu losses
                        -Print player weapon picks (#of times weapon is picked)
                        -Print Cpu weapon picks (#of times weapon is picked)
                        -Ask input from user ("Are you sure you want to quit? (y/n)")
                            -if y:
                                -Print("Thank you for playing, goodbye!")
                                -Program quits
                            -if n:
                                -Loop back to prompt asking user to play again (y/n)
                -if selection y:
                        -Loop back to prompt asking user one of three commands (r, p, or s?)
            -if player input selection ('s') and cpu selection ('p'):
                -Print("Looks like you won this time!")
                -Prompt user to play again (y/n)
                -if selection n:
                    -Print player Wins.
                        -Print player losses
                        -Print Cpu wins.
                        -Print Cpu losses
                        -Print player weapon picks (#of times weapon is picked)
                        -Print Cpu weapon picks (#of times weapon is picked)
                        -Ask input from user ("Are you sure you want to quit? (y/n)")
                            -if y:
                                -Print("Thank you for playing, goodbye!")
                                -Program quits
                            -if n:
                                -Loop back to prompt asking user to play again (y/n)
                    -if selection y:
                        -Loop back to prompt asking user one of three commands (r, p, or s?)
            -otherwise:
                -Print("Sorry, you lose!")
                    -Prompt user to play again (y/n)
                    -if selection n:
                        -Print player Wins.
                        -Print player losses
                        -Print Cpu wins.
                        -Print Cpu losses
                        -Print player weapon picks (#of times weapon is picked)
                        -Print Cpu weapon picks (#of times weapon is picked)
                        -Ask input from user ("Are you sure you want to quit? (y/n)")
                            -if y:
                                -Print("Thank you for playing, goodbye!")
                                -Program quits
                            -if n:
                                -Loop back to prompt asking user to play again (y/n)
                    -if selection y:
                        -Loop back to prompt asking user one of three commands (r, p, or s?)
